# %%
import dask.dataframe as dd
from dask.distributed import Client, TimeoutError, LocalCluster
from dask.diagnostics import ProgressBar

try:
    client = Client('tcp://localhost:8787', timeout='2s')
except OSError or TimeoutError:
    cluster = LocalCluster(scheduler_port=8787, n_workers=6, ip='localhost')
    client = Client(cluster)


client
# Out:
# 2022-11-07 16:13:24,175 - distributed.diskutils - INFO - Found stale lock file and directory '/var/folders/3t/s31r6vgj44n_g5t4csrvklwh0000gn/T/dask-worker-space/worker-q4hj2whn', purging
# 2022-11-07 16:13:24,176 - distributed.diskutils - INFO - Found stale lock file and directory '/var/folders/3t/s31r6vgj44n_g5t4csrvklwh0000gn/T/dask-worker-space/worker-_rr5ppyq', purging
# 2022-11-07 16:13:24,176 - distributed.diskutils - INFO - Found stale lock file and directory '/var/folders/3t/s31r6vgj44n_g5t4csrvklwh0000gn/T/dask-worker-space/worker-3kgvwyhz', purging
# 2022-11-07 16:13:24,177 - distributed.diskutils - INFO - Found stale lock file and directory '/var/folders/3t/s31r6vgj44n_g5t4csrvklwh0000gn/T/dask-worker-space/worker-s6kl96v1', purging
# 2022-11-07 16:13:24,178 - distributed.diskutils - INFO - Found stale lock file and directory '/var/folders/3t/s31r6vgj44n_g5t4csrvklwh0000gn/T/dask-worker-space/worker-w_kzrlxr', purging
# ...

# %%
licsdf = dd.read_csv(urlpath='Data/NYC_Dog_Licensing_Dataset.csv', \
    assume_missing=True)



bitedf = dd.read_csv(urlpath='Data/DOHMH_Dog_Bite_Data.csv',\
    assume_missing=True)


print(bitedf)

print(licsdf)
# Out:
# Dask DataFrame Structure:
#               UniqueID DateOfBite Species   Breed     Age  Gender SpayNeuter Borough  ZipCode
# npartitions=1
#                float64     object  object  object  object  object       bool  object  float64
#                    ...        ...     ...     ...     ...     ...        ...     ...      ...
# Dask Name: read-csv, 1 graph layer
# Dask DataFrame Structure:
#               AnimalName AnimalGender AnimalBirthYear BreedName  ZipCode LicenseIssuedDate LicenseExpiredDate ExtractYear
# npartitions=1
#                   object       object         float64    object  float64            object             object     float64
#                      ...          ...             ...       ...      ...               ...                ...         ...
# Dask Name: read-csv, 1 graph layer

# %%
print(licsdf.info())
licsdf = licsdf.rename(columns={'BreedName' : 'Breed'})
print(licsdf.info())
licsdf['Breed'] = licsdf['Breed'].str.lower()

bitedf['Breed'] = bitedf['Breed'].str.lower()


bitebreed = bitedf['Breed'].to_frame()
licsbreed = licsdf['Breed'].to_frame()

#joint = licsbreed.join(other=bitebreed, on='Breed', lsuffix='_L', rsuffix='_R', how='outer')

#joint = joint.compute()

#joint
# Out:
# <class 'dask.dataframe.core.DataFrame'>
# Columns: 8 entries, AnimalName to ExtractYear
# dtypes: object(5), float64(3)None
# <class 'dask.dataframe.core.DataFrame'>
# Columns: 8 entries, AnimalName to ExtractYear
# dtypes: object(5), float64(3)None

# %%
twt = dd.read_csv(urlpath='mental_health_tweets.csv', \
    assume_missing=True)

twt
# Out:
# Dask DataFrame Structure:
#                 tweet    time
# npartitions=1
#                object  object
#                   ...     ...
# Dask Name: read-csv, 1 graph layer
